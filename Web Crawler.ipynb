# %%
from requests import get
import pandas as pd

url = 'https://www.filmaffinity.com/es/topgen.php?genre=&fromyear=&toyear=&country=&nodoc'
response = get(url)


from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')


movie_containers = html_soup.find_all("div", {"class": "mc-info-container"})
movie_containers_scores = html_soup.find_all("div", {"class": "avg-rating"})


name = []
year = []
country = []
fa_rating = []



for i in range(0,29):
    movie = movie_containers[i]
    nombre = movie.a.text
    name.append(nombre)
    
    año = movie.find('div', class_ = 'mc-title')
    año2 = año.text[-8:-4]
    year.append(año2)

    pais = año.img['alt']
    country.append(pais)
    
    score = movie_containers_scores[i]
    score = score.text    
    fa_rating.append(score)




top30 = pd.DataFrame({'Nombre Pelicula': name,
'Año estreno': year,
'País': country,
'Valoración FA': fa_rating,
})
print(top30.info())
top30
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre Pelicula  29 non-null     object
#  1   Año estreno      29 non-null     object
#  2   País             29 non-null     object
#  3   Valoración FA    29 non-null     object
# dtypes: object(4)
# memory usage: 1.0+ KB
# None
#                           Nombre Pelicula Año estreno            País  \
# 0                             El padrino         1972  Estados Unidos
# 1                   El padrino. Parte II         1974  Estados Unidos
# 2   The Wire (Bajo escucha) (Serie de TV)        2002  Estados Unidos
# 3              Breaking Bad (Serie de TV)        2008  Estados Unidos
# 4                Doce hombres sin piedad         1957  Estados Unidos
# 5                  La lista de Schindler         1993  Estados Unidos
# 6                       Testigo de cargo         1957  Estados Unidos
# 7                     Luces de la ciudad         1931  Estados Unidos
# 8               Los Simpson (Serie de TV)        1989  Estados Unidos
# 9                        Cadena perpetua         1994  Estados Unidos
# 10                          Pulp Fiction         1994  Estados Unidos
# 11                      El gran dictador         1940  Estados Unidos
# 12                      Tiempos modernos         1936  Estados Unidos
# 13          Juego de tronos (Serie de TV)        2011  Estados Unidos
# 14                              El golpe         1973  Estados Unidos
# 15                          Ser o no ser         1942  Estados Unidos
# 16   Hermanos de sangre (Miniserie de TV)        2001  Estados Unidos
# 17                    Harakiri (Seppuku)         1962           Japón
# 18              Los Soprano (Serie de TV)        1999  Estados Unidos
# 19           El crepúsculo de los dioses         1950  Estados Unidos
# 20                      La vida es bella         1997          Italia
# 21       True Detective (Miniserie de TV)        2014  Estados Unidos
# 22                        Eva al desnudo         1950  Estados Unidos
# 23                    Senderos de gloria         1957  Estados Unidos
# 24                    Los siete samuráis         1954           Japón
# 25            Chernobyl (Miniserie de TV)        2019  Estados Unidos
# 26                              Amanecer         1927  Estados Unidos
# 27                             Perdición         1944  Estados Unidos
# 28                  El infierno del odio         1963           Japón
#
#    Valoración FA
# 0            9,0
# 1            8,9
# 2            8,9
# 3            8,8
# 4            8,7
# 5            8,6
# 6            8,6
# 7            8,6
# 8            8,6
# 9            8,6
# 10           8,6
# 11           8,6
# 12           8,6
# 13           8,6
# 14           8,6
# 15           8,5
# 16           8,5
# 17           8,5
# 18           8,5
# 19           8,5
# 20           8,5
# 21           8,5
# 22           8,5
# 23           8,4
# 24           8,4
# 25           8,4
# 26           8,4
# 27           8,4
# 28           8,4

# %%
# Out:
# range(0, 29)
